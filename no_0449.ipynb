# %% [markdown]
# 序列化是将数据结构或对象转换为一系列位的过程，以便它可以存储在文件或内存缓冲区中，或通过网络连接链路传输，以便稍后在同一个或另一个计算机环境中重建。
#
# 设计一个算法来序列化和反序列化 二叉搜索树 。 对序列化/反序列化算法的工作方式没有限制。 您只需确保二叉搜索树可以序列化为字符串，并且可以将该字符串反序列化为最初的二叉搜索树。
#
# 编码的字符串应尽可能紧凑。

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Codec:

    def in_order_search(self, root):
        if not root:
            return []
        left = self.in_order_search(root.left)
        right = self.in_order_search(root.right)

        return [str(root.val)] + left + right

    def serialize(self, root: TreeNode) -> str:
        """Encodes a tree to a single string.
        """
        in_order_seq = self.in_order_search(root)
        string = ','.join(in_order_seq)
        return string

    def deserialize(self, data: str) -> TreeNode:
        """Decodes your encoded data to tree.
        """
        if data == '': return None

        vals = [int(val) for val in data.split(',')]
        root = TreeNode(vals[0])

        for val in vals[1:]:
            self.put_val(root, val)

        return root
    
    def put_val(self, root, val):
        # if val == root.val: return root
        if val < root.val:
            if not root.left:
                root.left = TreeNode(val)
            else:
                self.put_val(root.left, val)
        if val > root.val:
            if not root.right:
                root.right = TreeNode(val)
            else:
                self.put_val(root.right, val)
        
# Your Codec object will be instantiated and called as such:
# Your Codec object will be instantiated and called as such:
node_1 = TreeNode(1)
node_2 = TreeNode(2)
node_3 = TreeNode(3)
node_4 = TreeNode(4)

node_3.left = node_1
node_3.right = node_4
node_1.right = node_2

ser = Codec()
deser = Codec()
tree = ser.serialize(node_3)
ans = deser.deserialize(tree)
pass
# return ans
